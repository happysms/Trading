# %%
import pyupbit
import pyfolio as pf
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import warnings
warnings.filterwarnings(action='ignore')
import numpy as np
import time
import pandas as pd
from sklearn.model_selection import train_test_split


mpl.rc('font', family='NanumGothic')
mpl.rc('axes', unicode_minus = False)

# %%
# from fbprophet import Prophet
# !pip install fbprophet
# !pip install --upgrade plotly
# Out:
# Collecting plotly
#   Downloading plotly-5.1.0-py2.py3-none-any.whl (20.6 MB)
#      |████████████████████████████████| 20.6 MB 127 kB/s eta 0:00:01
# Collecting tenacity>=6.2.0
#   Downloading tenacity-7.0.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied, skipping upgrade: six in /opt/anaconda3/lib/python3.8/site-packages (from plotly) (1.15.0)
# Installing collected packages: tenacity, plotly
# Successfully installed plotly-5.1.0 tenacity-7.0.0

# %%
def Volatility_predict(df, k, ticker):
    predicted_close_price = 0
    
    temp = pd.DataFrame()
    data = []
    for day in df.index:
        predicted_price = predict_price(day, ticker)
        data.append(predicted_price)
    
    df['predicted_price'] = data
    df['predicted_price'].fillna("backfill")

    df['range'] = (df['high'] - df['low']) * k
    df['target'] = df['open'] + df['range'].shift(1)
    df['ror'] = np.where((df['high'] > df['target']) & (df['open'] < df['predicted_price']),
                (df['close']*(1 + 0.005)) / (df['target']*(1 + 0.005)),
                1)
    return df

def predict_price(day, ticker):
    """Prophet으로 당일 종가 가격 예측"""
    global predicted_close_price
    df = pyupbit.get_ohlcv(ticker, interval="minute60", to = day)
    df = df.reset_index()
    df['ds'] = df['index']
    df['y'] = df['close']
    data = df[['ds','y']]
    model = Prophet()
    model.fit(data)
    future = model.make_future_dataframe(periods=24, freq='H')
    forecast = model.predict(future)
    closeDf = forecast[forecast['ds'] == forecast.iloc[-1]['ds'].replace(hour=9)]
    if len(closeDf) == 0:
        closeDf = forecast[forecast['ds'] == data.iloc[-1]['ds'].replace(hour=9)]
    closeValue = closeDf['yhat'].values[0]
    return closeValue

# 데이터를 불러온다.
def getdata(ticker="KRW-BTC", count = 200, to=None):
    dfs = [ ]
    date = to
    for i in range(count // 200 + 1):
        if i < count // 200 :
            df = pyupbit.get_ohlcv(ticker, to = date)
            date = df.index[0]
        elif count % 200 != 0 :
            df = pyupbit.get_ohlcv(ticker, to = date, count = count % 200)
        else:
            break
        dfs.append(df)
        time.sleep(0.05)

    df = pd.concat(dfs).sort_index()

    return df

def Volatility(df, k):
    """변동성 돌파 전략"""
    df['range'] = (df['high'] - df['low']) * k
    df['target'] = df['open'] + df['range'].shift(1)
    df['ror'] = np.where(df['high'] > df['target'],
                (df['close']*(1 + 0.005)) / (df['target']*(1 + 0.005)),
                1)
    return df


def Volatility_predict(df, k):
    predicted_close_price = 0
    
    for i in df.index:
        
    
    """변동성 돌파 전략"""
    df['range'] = (df['high'] - df['low']) * k
    df['target'] = df['open'] + df['range'].shift(1)
    df['ror'] = np.where(df['high'] > df['target'],
                (df['close']*(1 + 0.005)) / (df['target']*(1 + 0.005)),
                1)
    return df


def Volatility_ma5(df, k):
    """변동성 돌파 전략"""
    
    df['ma5'] = df['close'].rolling(5).mean().shift(1).fillna(method='backfill')
    df['range'] = (df['high'] - df['low']) * k
    df['target'] = df['open'] + df['range'].shift(1)
    df['ror'] = np.where((df['high'] > df['target']) & (df['open'] > df['ma5']),
                (df['close']*(1 + 0.005)) / (df['target']*(1 + 0.005)),
                1)
    return df


def backtester2(ticker="KRW-BTC", count = 200, to=None, strategy = None, ):
    df = getdata(ticker, count, to)

    df = Volatility_ma5(df, 0.5)

    df['hpr'] = df['ror'].cumprod()
    df['dd'] = (df['hpr'].cummax() - df['hpr']) / df['hpr'].cummax() * 100
    df['basic_ror'] = ((df['close'] / df['close'].shift(1))).cumprod()    
    (df['basic_ror'])[0] = 1
     
    return df

def backtester1(ticker="KRW-BTC", count = 200, to=None, strategy = None, ):
    df = getdata(ticker, count, to)

    df = Volatility(df, 0.5)

    df['hpr'] = df['ror'].cumprod()
    df['dd'] = (df['hpr'].cummax() - df['hpr']) / df['hpr'].cummax() * 100
    df['basic_ror'] = ((df['close'] / df['close'].shift(1))).cumprod()    
    (df['basic_ror'])[0] = 1
 
    return df

# %%
# 변동성 돌파 전략

tickers = [("KRW-BTC", "b"), ("KRW-ETH", "g") , ("KRW-XRP", "r") , ("kRW-ADA", "c") , ("KRW-LTC", "m"), ("KRW-DOGE", "y")]
tics = ["KRW-BTC" , "KRW-ETH" , "KRW-XRP" , "kRW-ADA" , "KRW-LTC" ,"KRW-DOGE"]
df_mdd = []

try:
    plt.figure(figsize = (20, 20))
    for ticker, color in tickers:
        df = backtester1(ticker ,count = 40, to = "2021-05-07")
        print(ticker + " 알고리즘 적용 수익률 : " + str((df['hpr'])[-1]) + " 알고리즘 미적용 수익률 : " + str((df['basic_ror'])[-1])) 
        
        
        plt.subplot(311)
        plt.plot(df.index, df['hpr']*100, color = color, label = ticker)
        plt.legend(loc='best')
        plt.title("Strategy O")
        plt.ylabel("rate of return")
        plt.grid(True)

        plt.subplot(312)
        plt.plot(df.index, df['basic_ror'] * 100, color = color, label = ticker)
        plt.legend(loc='best')
        plt.title("Strategy X")
        plt.ylabel("rate of return")
        plt.grid(True)

        df_mdd.append(df["dd"].max())


    x = np.arange(len(tickers))
    plt.subplot(313)
    plt.bar(x , df_mdd , align='edge', edgecolor="gray", linewidth= 2, width=0.3, tick_label = tics) 


except Exception as e:
    print(e)
# Out:
# KRW-BTC 알고리즘 적용 수익률 : 1.07671264497084 알고리즘 미적용 수익률 : 1.024339743494258
# KRW-ETH 알고리즘 적용 수익률 : 1.2884887502569105 알고리즘 미적용 수익률 : 2.092966060009838
# KRW-XRP 알고리즘 적용 수익률 : 2.366903576401882 알고리즘 미적용 수익률 : 2.9711246200607895
# kRW-ADA 알고리즘 적용 수익률 : 1.0807127284675115 알고리즘 미적용 수익률 : 1.4195804195804196
# KRW-LTC 알고리즘 적용 수익률 : 1.0667114363194838 알고리즘 미적용 수익률 : 1.9554355165428776
# KRW-DOGE 알고리즘 적용 수익률 : 5.991172189631334 알고리즘 미적용 수익률 : 10.942812982998452

# %%
# 변동성 돌파 전략 + 5일선 

tickers = [("KRW-BTC", "b"), ("KRW-ETH", "g") , ("KRW-XRP", "r") , ("kRW-ADA", "c") , ("KRW-LTC", "m"), ("KRW-DOGE", "y")]
tics = ["KRW-BTC" , "KRW-ETH" , "KRW-XRP" , "kRW-ADA" , "KRW-LTC" ,"KRW-DOGE"]
df_mdd = []

try:
    plt.figure(figsize = (20, 20))
    for ticker, color in tickers:
        df = backtester2(ticker ,count = 50)
        print(ticker + " 알고리즘 적용 수익률 : " + str((df['hpr'])[-1]) + " 알고리즘 미적용 수익률 : " + str((df['basic_ror'])[-1])) 

        plt.subplot(311)
        plt.plot(df.index, df['hpr']*100, color = color, label = ticker)
        plt.legend(loc='best')
        plt.title("Strategy O")
        plt.ylabel("rate of return")
        plt.grid(True)

        plt.subplot(312)
        plt.plot(df.index, df['basic_ror'] * 100, color = color, label = ticker)
        plt.legend(loc='best')
        plt.title("Strategy X")
        plt.ylabel("rate of return")
        plt.grid(True)

        df_mdd.append(df["dd"].max())


    x = np.arange(len(tickers))
    plt.subplot(313)
    plt.bar(x , df_mdd , align='edge', edgecolor="gray", linewidth= 2, width=0.3, tick_label = tics) 


except Exception as e:
#    print(e)
# Out:
# KRW-BTC 알고리즘 적용 수익률 : 0.9880554349645968 알고리즘 미적용 수익률 : 0.8023581254093969
# KRW-ETH 알고리즘 적용 수익률 : 1.0286118543375184 알고리즘 미적용 수익률 : 0.8247761194029852
# KRW-XRP 알고리즘 적용 수익률 : 1.0322701045521567 알고리즘 미적용 수익률 : 0.5225589225589221
# kRW-ADA 알고리즘 적용 수익률 : 1.0760754908586208 알고리즘 미적용 수익률 : 0.8197530864197536
# KRW-LTC 알고리즘 적용 수익률 : 1.0368682938964808 알고리즘 미적용 수익률 : 0.6373157486423582
# KRW-DOGE 알고리즘 적용 수익률 : 0.948784217949201 알고리즘 미적용 수익률 : 0.6000000000000002

# %%
# Best K값 찾기

df = getdata("KRW-BTC", 200)
df['basic_ror'] = ((df['close'] / df['close'].shift(1))).cumprod()    
(df['basic_ror'])[0] = 1

plt.figure(figsize = (20, 8))

color = ['b', 'g', 'r', 'c' , 'm', 'y' , 'k']

for i, k in enumerate(np.arange(0.1, 0.7, 0.1)):
    df = Volatility(df, k)
    df['hpr'] = df['ror'].cumprod()
    df['dd'] = (df['hpr'].cummax() - df['hpr']) / df['hpr'].cummax() * 100
    print(ticker + " 알고리즘 적용 수익률 : " + str((df['hpr'])[-1]) + " Mdd : " + str((df['dd'].max()))) 
    plt.plot(df.index, df['hpr']*100, color = color[i], label = str(k))

    
plt.plot(df.index, df['basic_ror']*100, color = 'k', linestyle = '--', label = "basic")
plt.legend(loc='best')

plt.title("Best K Search")
plt.ylabel("rate of return")
plt.grid(True)
# Out:
# KRW-DOGE 알고리즘 적용 수익률 : 1.1029094441052827 Mdd : 62.71944753762859
# KRW-DOGE 알고리즘 적용 수익률 : 1.0425092505095366 Mdd : 53.13200913176643
# KRW-DOGE 알고리즘 적용 수익률 : 1.5683891564628964 Mdd : 27.86198209796688
# KRW-DOGE 알고리즘 적용 수익률 : 1.5325851224332172 Mdd : 19.1087843638144
# KRW-DOGE 알고리즘 적용 수익률 : 1.4483797015192554 Mdd : 18.02801187485495
# KRW-DOGE 알고리즘 적용 수익률 : 1.5866214704815378 Mdd : 8.82304848077386

# %%
# Prophet + 변동성 돌파 전략

# 24시간 뒤의 가격이 시가보다 높을 것이라고 예측하면 매수


def Volatility_predict(df, k, ticker):
    predicted_close_price = 0
    
    temp = pd.DataFrame()
    data = []
    for day in df.index:
        predicted_price = predict_price(day, ticker)
        data.append(predicted_price)
    
    df['predicted_price'] = data
    # df['predicted_price'].fillna("backfill")

    df['range'] = (df['high'] - df['low']) * k
    df['target'] = df['open'] + df['range'].shift(1)
    df['ror'] = np.where((df['high'] > df['target']) & (df['open'] < df['predicted_price']),
                (df['close']*(1 + 0.005)) / (df['target']*(1 + 0.005)),
                1)
    return df


def backtester3(ticker="KRW-BTC", count = 200, to=None, strategy = None, ):
    df = getdata(ticker, count, to)

    df = Volatility_predict(df, 0.5, ticker)

    df['hpr'] = df['ror'].cumprod()
    df['dd'] = (df['hpr'].cummax() - df['hpr']) / df['hpr'].cummax() * 100
    df['basic_ror'] = ((df['close'] / df['close'].shift(1))).cumprod()    
    (df['basic_ror'])[0] = 1
 
    return df

def predict_price(day, ticker):
    """Prophet으로 당일 종가 가격 예측"""
    global predicted_close_price
    df = pyupbit.get_ohlcv(ticker, interval="minute60", to = day)
    df = df.reset_index()
    df['ds'] = df['index']
    df['y'] = df['close']
    data = df[['ds','y']]
    model = Prophet()
    model.fit(data)
    future = model.make_future_dataframe(periods=24, freq='H')
    forecast = model.predict(future)
    closeDf = forecast[forecast['ds'] == forecast.iloc[-1]['ds'].replace(hour=9)]
    if len(closeDf) == 0:
        closeDf = forecast[forecast['ds'] == data.iloc[-1]['ds'].replace(hour=9)]
    closeValue = closeDf['yhat'].values[0]
    return closeValue


tickers = [("KRW-BTC", "b"), ("KRW-ETH", "g") , ("KRW-XRP", "r") , ("kRW-ADA", "c") , ("KRW-LTC", "m"), ("KRW-DOGE", "y")]
tics = ["KRW-BTC" , "KRW-ETH" , "KRW-XRP" , "kRW-ADA" , "KRW-LTC" ,"KRW-DOGE"]
df_mdd = []

try:
    plt.figure(figsize = (20, 20))
    for ticker, color in tickers:
        df = backtester3(ticker ,count = 10 , to = "2021-05-01")
        print(ticker + " 알고리즘 적용 수익률 : " + str((df['hpr'])[-1]) + " 알고리즘 미적용 수익률 : " + str((df['basic_ror'])[-1])) 
        
        
        plt.subplot(311)
        plt.plot(df.index, df['hpr']*100, color = color, label = ticker)
        plt.legend(loc='best')
        plt.title("Strategy O")
        plt.ylabel("rate of return")
        plt.grid(True)

        plt.subplot(312)
        plt.plot(df.index, df['basic_ror'] * 100, color = color, label = ticker)
        plt.legend(loc='best')
        plt.title("Strategy X")
        plt.ylabel("rate of return")
        plt.grid(True)

        df_mdd.append(df["dd"].max())


    x = np.arange(len(tickers))
    plt.subplot(313)
    plt.bar(x , df_mdd , align='edge', edgecolor="gray", linewidth= 2, width=0.3, tick_label = tics) 


except Exception as e:
    print(e)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-119-03bc27fb1119> in <module>
#      18     closeValue = closeDf['yhat'].values[0]
#      19     predicted_close_price = closeValue
# ---> 20 predict_price("KRW-BTC")
#      21 schedule.every().hour.do(lambda: predict_price("KRW-BTC"))
#      22 print(predicted_close_price)
#
# <ipython-input-119-03bc27fb1119> in predict_price(ticker)
#       9     df['y'] = df['close']
#      10     data = df[['ds','y']]
# ---> 11     model = Prophet()
#      12     model.fit(data)
#      13     future = model.make_future_dataframe(periods=24, freq='H')
#
# NameError: name 'Prophet' is not defined
